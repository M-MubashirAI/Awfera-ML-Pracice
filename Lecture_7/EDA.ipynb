# %% [markdown]
# # Lecture 7: Exploratory Data Analysis(EDA)
#
# ## Course: AWFERA Machine Learning
# ## Instructor: Dr.Shazia Saqib
# ## Student: Mubashir Malik
# ## Email: mubshirmalik414@gmail.com
#
# ---

# %% [markdown]
# ### 📊 Exploratory Data Analysis
#
# **EDA (Exploratory Data Analysis)** is the process of exploring and understanding data before modeling. It involves using **statistics** and **visualizations** to find patterns, detect outliers, and check assumptions.
#
# Tools like `pandas`, `seaborn`, and `matplotlib` are commonly used. It helps in data cleaning, feature selection, and building better models.
#
# In short, **EDA gives you a solid grasp of your dataset.**

# %% [markdown]
# #### Import the Libraries

# %%
import pandas as pd                   # for data manipulation and analysis
import numpy as np                    # for numerical operations and working with arrays
import matplotlib.pyplot as plt       # for data visualization (plots and graphs)
import seaborn as sns                 # For advanced data visualization (built on matplotlib)
import sklearn                        # For machine learning algorithms and model evaluation
# To display plots inline in Jupyter Notebook
# %matplotlib inline

# %%
# Set default figure size to 10 (width) x 5 (height) inches
plt.rcParams['figure.figsize'] = [10, 5]

# %%
import warnings
warnings.filterwarnings('ignore')   # ignore all warnings messages
warnings.simplefilter(action='ignore', category=FutureWarning) # ignore future warnings specifically

# %% [markdown]
# ### 📘 Seaborn Official Documentation
#
# For detailed documentation and examples, refer to the official Seaborn Documentation:
#
# 🔗 [Seaborn Officical Documentation](https://seaborn.pydata.org/tutorial.html)

# %% [markdown]
# ### 📊 Types of Plots in Seaborn
#
# ![Types of Plots in Seaborn](![Screenshot 2025-05-09 114753.png](<attachment:Screenshot 2025-05-09 114753.png>))

# %% [markdown]
# ---

# %% [markdown]
# ### Seaborn Functionality
#
# Seaborn offers a lot of functionality which makes it effective for many data visualization tasks. These functionalities are listed below:
#
# - Seaborn provides a dataset-oriented API to examine relationships between variables.
# - It provides functions to fit and visualize linear regression models for different types of independent and dependent variables.
# - Seaborn provides functions for visualizing univariate and bivariate distributions and for comparing them between subsets of data.
# - It provides plotting functions for using categorical variables to show observations or aggregate statistics.
# - It helps us to visualize matrices of data and use clustering algorithms to discover structure in those matrices.
# - Seaborn provides a plotting function to plot statistical time series data. The function provides flexible estimation and representation of uncertainty around the estimate.
# - It provides tools for choosing styles, colour palettes, palette widgets and utility functions. These tools help us to make beautiful plots that reveal patterns in the data.
# - It provides several built-in themes for producing stylish looking Matplotlib graphics.

# %% [markdown]
# # Seaborn Colour Palette
#
# Colour plays a very important role in data visualization. Colour adds various dimensions to a plot when used effectively. A palette means a flat surface on which a painter mixes paints.
#
# Seaborn provides a function called `color_palette()`. It can be used to give colours to plots and add aesthetic value to them. It returns a list of colors defining a color palette.
#
# There are several readily available Seaborn palettes. These are:
#
# - Deep
# - Muted
# - Bright
# - Pastel
# - Dark
# - Colorblind
#
# Besides these, we can also create new palettes.
#
# There is another function `seaborn.palplot()` which deals with color palettes. This function plots the color palette as a horizontal array.

# %% [markdown]
# ---

# %% [markdown]
# ### Categorical Color Palettes
#
# Qualitative or Categorical palettes are best suitable to plot the categorical data as follows:

# %%
current_palette = sns.color_palette()  # Get the current color palette from seaborn
sns.palplot(current_palette) # Display the current color palette
plt.show() # Display the current color palette

# %% [markdown]
# ### Continuous Coloar Palettes
#
# Sequential plot are suitable to express the distribution of data ranging from relative lower values to higher values within a range.
# Appending an additional character "s" to the color pass to the color parameter will plot sequetial plot.
#
# We need append 's' to the parameter like 'Green' as follows:

# %%
current_palette1 = sns.color_palette() 
sns.palplot(sns.color_palette("Reds")) # Display the red color palette
plt.show() # Display the red color palette

# %% [markdown]
# # Diverging Color palette
# Diverging palette are used two different colors. Each color represent the variations in the value ranging from a common point in either direction. We assume plotting the data ranging from -1 to 1. The value from 1 to 0 to takes one color and 0 to +1 takes another color.
#
# By default, the values are centered from zero. We can contro with it parameter center by passing a value as follow:

# %%
current_palette2 = sns.color_palette()
sns.palplot(sns.color_palette("BrBG", 20)) # Display the brown-green color palette
plt.show() # Display the brown-green color palette

# %% [markdown]
# # Seaborn on Titanic Dataset
#
# In this tutorial, we will learn to use different **Seaborn** plot functions to get insights from data. We will use the **Titanic dataset** to experiment with these types of Seaborn plots.
#
# ---
#
# ## Prerequisites
#
# - You should have a basic understanding of computer programming terminologies.
# - A basic understanding of **Python** and any programming language is a plus.
# - The **Seaborn** library is built on top of **Matplotlib**.
# - Having a basic idea of **Matplotlib** will help you understand this tutorial in a better way.

# %% [markdown]
# ### Sequential Color palette

# %%
current_palette3 = sns.color_palette()
sns.palplot(sns.color_palette("colorblind")) # Display the colorblind-friendly palette
plt.show()

# %% [markdown]
# ## Import the Data
#
# Let's extract our **Titanic** data from the `.csv` file, create a **Pandas DataFrame**, and look at the available indicators:
#
# - **Survived**: Outcome of survival (`0 = No`, `1 = Yes`)
# - **Pclass**: Socio-economic class (`1 = Upper class`, `2 = Middle class`, `3 = Lower class`)
# - **Name**: Name of passenger
# - **Sex**: Sex of the passenger
# - **Age**: Age of the passenger (Some entries contain `NaN`)
# - **SibSp**: Number of siblings and spouses of the passenger aboard
# - **Parch**: Number of parents and children of the passenger aboard
# - **Ticket**: Ticket number of the passenger
# - **Fare**: Fare paid by the passenger
# - **Cabin**: Cabin number of the passenger (Some entries contain `NaN`)
# - **Embarked**: Port of embarkation of the passenger (`C = Cherbourg`, `Q = Queenstown`, `S = Southampton`)

# %%
df = pd.read_csv("titanic_dataset.csv") # Load the Titanic dataset from a CSV file

# %%
# Basic Information
df.shape # Display the shape of the DataFrame (number of rows and columns)
# Out:
# (891, 12)

# %%
df.info() # Display information about the DataFrame (data types, non-null counts, etc.)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head() # Display the first 5 rows of the DataFrame
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() # Display the last 5 rows of the DataFrame
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # **Data Visualization**
#
#
# *   Data visualization is the graphical representaion of information and data.
# *   In the world of Big Data, data visualization tools and technologies are essential to analyze massive amounts of information and make data-driven decisions.
# # **Seaborn:**
#
#
# *   Seaborn is a python data visulization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ## Simple Graphs
#
# **Survival rate by Passenger Class**

# %%
# Create figure and axis
plt.figure(figsize=(10, 6))
# Create a count plot for the 'Survived' column
sns.countplot(x="Pclass", hue="Survived", data=df, palette="Set2")
# Set the title and labels  
plt.title("Survival rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.legend(labels=["Did not survive", "Survived"])
plt.show() # Display the plot

# %%
# Survival rate by Gender
plt.figure(figsize=(10, 6))
sns.countplot(x = "Sex", hue = "Survived", data = df)
plt.title("Survived Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(labels=["Did not survive", "Survived"])
plt.show() # Display the plot

# %%
# Age distribution of passengers
plt.figure(figsize=(12, 7))
sns.histplot(df['Age'], bins = 30, kde=True, color="blue")
plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.axvline(df['Age'].mean(), color='red', linestyle='--', label='Mean Age')
plt.axvline(df['Age'].median(), color='green', linestyle='--', label='Median Age')
plt.legend()
plt.show()

# %% [markdown]
# ## Distribution Plots
#
# Distribution of data is the foremost thing that we need to understand while analysing the data. Here, we will see how **Seaborn** helps us in understanding the distribution of our data.
#
# ### 📊 `distplot`
#
# The `distplot()` function provides the most convenient way to take a quick look at **univariate distribution**.
# This function will plot a **histogram** that fits the **Kernel Density Estimation (KDE)** of the data.
#
# Now let's plot the histogram of **Number of parents and children of the passenger aboard (`parch`)**.

# %%
sns.histplot(df['Parch'], bins = 30, kde=False, color="blue")
plt.show() # Display the histogram of age distribution

# %% [markdown]
# As we can see, that most passenger don't have neither parents nor children aboard

# %% [markdown]
# ### `kdeplot`
#
# **Kernel Density Estimation (KDE)** is a way to estimate the **probability density function** of a continuous random variable.
# It is used for **non-parametric analysis**.
#
# - Setting the `hist` flag to `False` in `distplot()` will yield the **KDE plot**.
# - For **bivariate distribution**, we can plot a KDE by using `jointplot()`.
#   Pass value `'kde'` to the parameter `kind` to plot the kernel plot.
#
# > **Note:**
# > `distplot(data)` is used to visualize the **parametric distribution** of data.
# > It plots **both KDE and histogram** on the same figure.

# %%
sns.distplot(df['Age'], bins=30, color="blue", hist=False)
plt.show() # Display the distribution plot of age distribution

# %% [markdown]
# As we can see that most of the passenger has the age the between 20 to 40.

# %%
plt.figure(figsize= (18,18))
sns.distplot(df['Age'])
plt.show() # Display the distribution plot of age distribution

# %% [markdown]
# ## Relational Plots
#
# ### `relplot()`
#
# **Figure-level interface** for drawing relational plots onto a `FacetGrid`.
#
# The function `relplot()` is named that way because it is designed to visualize many different **statistical relationships**.
#
# - While **scatter plots** are a highly effective way of visualizing relationships,
# - Relationships where one variable represents a **measure of time** are better represented by a **line plot**.
#
# The `relplot()` function has a convenient `kind` parameter that allows you to **easily switch** between different types of relational plots (e.g., `'scatter'`, `'line'`).

# %%
plt.figure(figsize=(12, 12))
sns.relplot(x="Age", y="Fare", col="Pclass", hue="Sex", style="Sex",kind="line", data=df) # scatter can be used instead of "line" plot
plt.show() # Display the scatter plot of age vs fare with different

# %% [markdown]
# ### `scatterplot`
# **Scatter plot** is the most convenient way to visualize the distribution where each observation is represented in two -dimensional plot via x and y axis.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Age", y="Fare", hue="Sex", data=df)
plt.show()

# %% [markdown]
# ### `lineplot()`
#
# Draw a **line plot** with the possibility of several **semantic groupings**.
#
# - The relationship between `x` and `y` can be shown for **different subsets of the data** using the `hue`, `size`, and `style` parameters.
# - These parameters control what **visual semantics** are used to identify different subsets.
# - You can represent up to **three dimensions** independently using all three semantic types.
#
# > ⚠️ Note: While it's possible to map three semantic types at once, such plots can be **hard to interpret** and may be **ineffective**.
# Using **redundant semantics** (e.g., both `hue` and `style` for the same variable) can improve **accessibility** of your plots.
#
# - The default treatment of `hue` (and to some extent, `size`) depends on whether the variable is **numeric** or **categorical**.
#   - **Numeric** variables use a **sequential colormap** by default.
#   - The **legend** will show regular “ticks” with values, even if they don’t exist in the dataset.
#   - This behavior is **customizable** via additional parameters.
#
# By default, the plot:
# - **Aggregates** over multiple `y` values at each `x`.
# - Shows an **estimate of central tendency** and a **confidence interval** for that estimate.

# %%
plt.figure(figsize=(8, 8))
sns.lineplot(x="Age", y="Fare", hue= "Sex",style="Sex", data=df)
plt.show() # Display the line plot of age vs fare with different

# %% [markdown]
# # Categorical Plot
#
# When one or both the variables under study are categorical, we use plots like `striplot()`, `swarmplot()`, etc. Seaborn provides an interface to do so.
#
# ##  `barplot`
#
# The `barplot()` shows the relation between a categorical variable and a continuous variable. The data is represented in rectangular bars where the length of the bar represents the proportion of the data in that category. Bar plot represents the estimate of central tendency.
#
# > **Note:** Don't confuse Bar Plot and Histogram. Please refer back to section **2.1. `distplot`** to see the difference.

# %%
sns.barplot(x="Sex", y="Survived", data=df, palette="Set2", hue="Pclass")
plt.show() # Display the bar plot of survival

# %% [markdown]
# As we can see that more women survived than men

# %% [markdown]
# ## `stripplot`
# **stripplot()** is used when one of the variable under study is categorical. It represents the data in sorted order along any one of the axis.

# %%
plt.figure(figsize=(12, 8))
sns.stripplot(x="Sex", y="Age", hue="Sex", data=df)
plt.legend(labels=["Male","Female"])
plt.show() # Display the strip plot

# %% [markdown]
# To avoid the overlapping of the points, we can use the jitter to add some random noise to the data. This parameter will adjust the positions along the categorical axis. But Another option which can be used as an alternate to ‘Jitter’ is function swarmplot().

# %% [markdown]
# ## `swarmplot`
# This function positions each point of scatter plot on the categorical axis and thereby avoids overlapping points:

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x = "Sex", y = "Age", hue = "Sex", data = df)
plt.legend(labels=["male", "female"])
plt.show() # Display the swarm plot

# %% [markdown]
# **We can say that more passengers approximately between 18 to 40.**

# %% [markdown]
# ## `Boxplot`
#
# `Boxplot` is a convenient way to visualize the distribution of data through their quartiles. Box plots usually have vertical lines extending from the boxes which are termed as **whiskers**. These whiskers indicate variability outside the upper and lower quartiles.
#
# Hence, Box Plots are also termed as:
#
# - **Box-and-whisker plot**
# - **Box-and-whisker diagram**
#
# Any **outliers** in the data are plotted as individual points.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="Survived", y="Age", data=df, palette="Set2")
plt.show()

# %% [markdown]
# **We have some outliers for passengers survery through their age.**

# %% [markdown]
#  ## `violinplot`
# **Violin Plots** are a combination of the **box plot** with the **kernel density estimates**. So, these plots are easier to analyze and understand the distribution of the data.

# %%
sns.violinplot(x="Survived", y="Age", hue='Sex', data=df, palette="Set2")
plt.show()

# %% [markdown]
# The quartile and whisker values from the boxplot are shown inside the violin. As the violin plot uses KDE, the wider portion of violin indicates the higher density and narrow region represents relatively lower density. The Inter-Quartile range in boxplot and higher density portion in kde fall in the same region of each category of violin plot

# %% [markdown]
# ## `countplot`
# A special case in **barplot** is to show the no of observations in each category rather than computing a statistic for a second variable. For this, we use `countplot()`.

# %%
sns.countplot(x="Survived", data=df, palette="Blues");
plt.show()

# %% [markdown]
# ## `pointplot`
# **Point plots** serve same as **bar plots** but in a different style. Rather than the full bar, the value of the estimate is represented by the point at a certain height on the other axis.

# %%
plt.subplots(figsize=(10, 8))
sns.pointplot(x="Sex", y="Survived", hue="Pclass", data=df, palette="Set2")
plt.show()

# %% [markdown]
# **We can see the average number of survivals of male and female in each class. From the plot we can understand that more number of females survived than males. In both males and females more number of survivals are from first class.**
#
# **Plot says that, the number of passengers in the third class are higher than first and second class.**

# %% [markdown]
# ---

# %% [markdown]
# # Regression Plots
#
# Most of the time, we use datasets that contain multiple quantitative variables, and the goal of an analysis is often to relate those variables to each other. This can be done through **regression lines**.
#
# While building regression models, we often check for **multicollinearity**, where we analyze the correlation between all combinations of continuous variables. If multicollinearity exists, necessary actions are taken to remove it.
#
# There are two main functions in **Seaborn** to visualize a linear relationship determined through regression:
#
# - `regplot()`
# - `lmplot()`
#
# ### `lmplot`
#
# `lmplot()` has `data` as a required parameter, and the `x` and `y` variables must be specified as **strings**.
# This data format is called **"long-form"** data.

# %%
sns.lmplot(x="Age", y="Fare", data=df, palette="Set2")
plt.show()

# %% [markdown]
#  ### `regplot`
# **regplot** accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame.

# %%
plt.subplots(figsize=(10, 10))
sns.regplot(x="Age", y="Fare", data=df)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
#  # Matrix plots
#
#
# ##  `heatmap`
# Visualizing data with **heatmaps** is a great way to do exploratory data analysis, when you have a data set with multiple variables. Heatmaps can reveal general pattern in the dataset, instantly. And it is very easy to make beautiful heatmaps with Seaborn library in Python.
#
# Now let's plot the correlation matrix of our data with a heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate correlation matrix
corr = numeric_df.corr()

# %%
# Plot heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap="YlGnBu", annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Multi-plot Grids
#
# ###  Facet Grids
#
# A useful approach to explore medium-dimensional data is by drawing multiple instances of the same plot on different subsets of your dataset. This technique is commonly called **“lattice”**, or **“trellis”** plotting, and it is related to the idea of **“small multiples”**. To use these features, your data must be in a **Pandas DataFrame**.
#
# **FacetGrid** forms a matrix of panels defined by `row` and `column` by dividing the variables. Due to these panels, a single plot appears as multiple plots. It is very helpful to analyze all combinations in two discrete variables.
#
# The **FacetGrid** object takes a DataFrame as input and the names of the variables that will form the `row`, `column`, or `hue` dimensions of the grid. The variables should be **categorical**, and the data at each level of the variable will be used for a facet along that axis.
#
# The advantage of using Facet is that we can input another variable into the plot. We can create multiple column facets and align them with the rows of the grid.
#
# ### `FacetGrid.map()`
#
# The main approach for visualizing data on this grid is with the **`FacetGrid.map()`** method.

# %%
# initialize the FacetGrid object
plt.figure(figsize=(10, 10))
g = sns.FacetGrid(df, col='Survived', row='Pclass')

g.map(plt.hist, 'Age')
g.add_legend()
plt.show()
